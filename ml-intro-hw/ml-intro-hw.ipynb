# %% [markdown]
# # SkillFactory
# ## Введение в ML, введение в sklearn

# %% [markdown]
# В этом задании мы с вами рассмотрим данные с конкурса [Задача предсказания отклика клиентов ОТП Банка](http://www.machinelearning.ru/wiki/index.php?title=%D0%97%D0%B0%D0%B4%D0%B0%D1%87%D0%B0_%D0%BF%D1%80%D0%B5%D0%B4%D1%81%D0%BA%D0%B0%D0%B7%D0%B0%D0%BD%D0%B8%D1%8F_%D0%BE%D1%82%D0%BA%D0%BB%D0%B8%D0%BA%D0%B0_%D0%BA%D0%BB%D0%B8%D0%B5%D0%BD%D1%82%D0%BE%D0%B2_%D0%9E%D0%A2%D0%9F_%D0%91%D0%B0%D0%BD%D0%BA%D0%B0_%28%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%29)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12,5)

# %% [markdown]
# ### Грузим данные

# %% [markdown]
# Считаем описание данных

# %%
df_descr = pd.read_csv('data/otp_description.csv', sep='\t', encoding='utf8')

# %%
df_descr
# Out:
#                           ПОЛЕ  \
# 0                 AGREEMENT_RK
# 1                          AGE
# 2            SOCSTATUS_WORK_FL
# 3            SOCSTATUS_PENS_FL
# 4                       GENDER
# 5                  CHILD_TOTAL
# 6                   DEPENDANTS
# 7                    EDUCATION
# 8               MARITAL_STATUS
# 9                 GEN_INDUSTRY
# 10                   GEN_TITLE
# 11                ORG_TP_STATE
# 12             ORG_TP_FCAPITAL
# 13                     JOB_DIR
# 14               FAMILY_INCOME
# 15             PERSONAL_INCOME
# 16        REG_ADDRESS_PROVINCE
# 17       FACT_ADDRESS_PROVINCE
# 18     POSTAL_ADDRESS_PROVINCE
# 19                 TP_PROVINCE
# 20                   REGION_NM
# 21                 REG_FACT_FL
# 22                FACT_POST_FL
# 23                 REG_POST_FL
# 24            REG_FACT_POST_FL
# 25         REG_FACT_POST_TP_FL
# 26              FL_PRESENCE_FL
# 27                    OWN_AUTO
# 28                 AUTO_RUS_FL
# 29              HS_PRESENCE_FL
# 30             COT_PRESENCE_FL
# 31             GAR_PRESENCE_FL
# 32            LAND_PRESENCE_FL
# 33                      CREDIT
# 34                        TERM
# 35                 FST_PAYMENT
# 36              DL_DOCUMENT_FL
# 37             GPF_DOCUMENT_FL
# 38            FACT_LIVING_TERM
# 39                   WORK_TIME
# 40               FACT_PHONE_FL
# 41                REG_PHONE_FL
# 42                GEN_PHONE_FL
# 43              LOAN_NUM_TOTAL
# 44             LOAN_NUM_CLOSED
# 45               LOAN_NUM_PAYM
# 46                LOAN_DLQ_NUM
# 47                LOAN_MAX_DLQ
# 48            LOAN_AVG_DLQ_AMT
# 49            LOAN_MAX_DLQ_AMT
# 50  PREVIOUS_CARD_NUM_UTILIZED
#
#                                              ОПИСАНИЕ
# 0          уникальный идентификатор объекта в выборке
# 1                                     возраст клиента
# 2   социальный статус клиента относительно работы ...
# 3   социальный статус клиента относительно пенсии ...
# 4                 пол клиента (1- женщины, 0-мужчины)
# 5                            количество детей клиента
# 6                       количество иждивенцев клиента
# 7                                         образование
# 8                                  семейное положение
# 9                              отрасль работы клиента
# 10                                          должность
# 11                       форма собственности компании
# 12                  отношение к иностранному капиталу
# 13          направление деятельности в нутри компании
# 14               семейный доход (несколько категорий)
# 15                    личный доход клиента (в рублях)
# 16                        область регистрации клиента
# 17            область фактического пребывания клиента
# 18                             почтовый адрес область
# 19  область торговой точки, где клиент брал послед...
# 20                                          регион РФ
# 21  адрес регистрации и адрес фактического пребыва...
# 22  адрес фактического пребывания клиента и его по...
# 23  адрес регистрации клиента и его почтовый адрес...
# 24  почтовый, фактический и адрес регистрации совп...
# 25  область регистрации, фактического пребывания, ...
# 26  наличие в собственности квартиры (1 - есть, 0 ...
# 27                кол-во автомобилей в собственности
# 28  наличие в собственности автомобиля российского...
# 29  наличие в собственности загородного дома (1 - ...
# 30  наличие в собственности котеджа (1 - есть, 0 -...
# 31  наличие в собственности гаража (1 - есть, 0 - ...
# 32  наличие в собственности земельного участка (1 ...
# 33        сумма последнего кредита клиента (в рублях)
# 34                                       срок кредита
# 35                    первоначальный взнос (в рублях)
# 36  в анкете клиент указал водительское удостовере...
# 37  в анкете клиен указал ГПФ (1 - указал, 0 - не ...
# 38  количество месяцев проживания по месту фактиче...
# 39          время работы на текущем месте (в месяцах)
# 40  наличие в заявке телефона по фактическому мест...
# 41     наличие в заявке телефона по месту регистрации
# 42                 наличие в заявке рабочего телефона
# 43                            количество ссуд клиента
# 44                 количество погашенных ссуд клиента
# 45         количество платежей, которые сделал клиент
# 46          количество просрочек, допущенных клиентом
# 47  номер максимальной просрочки, допущенной клиентом
# 48                 средняя сумма просрочки (в рублях)
# 49            максимальная сумма просрочки (в рублях)
# 50  количество уже утилизированных карт ( если пус...

# %% [markdown]
# Считаем обучающую выборки и тестовую (которую мы как бы не видим)

# %%
df_train = pd.read_csv('data/otp_train.csv', sep='\t', encoding='utf8')

# %%
df_train.shape
# Out:
# (15223, 52)

# %%
df_test = pd.read_csv('data/otp_test.csv', sep='\t', encoding='utf8')

# %%
df_test.shape
# Out:
# (14910, 52)

# %%
df_train.head()
# Out:
#    AGREEMENT_RK  TARGET  AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  GENDER  \
# 0      59910150       0   49                  1                  0       1
# 1      59910230       0   32                  1                  0       1
# 2      59910525       0   52                  1                  0       1
# 3      59910803       0   39                  1                  0       1
# 4      59911781       0   30                  1                  0       0
#
#    CHILD_TOTAL  DEPENDANTS            EDUCATION  MARITAL_STATUS  \
# 0            2           1  Среднее специальное  Состою в браке
# 1            3           3              Среднее  Состою в браке
# 2            4           0     Неполное среднее  Состою в браке
# 3            1           1               Высшее  Состою в браке
# 4            0           0              Среднее  Состою в браке
#
#              ...             REG_PHONE_FL GEN_PHONE_FL LOAN_NUM_TOTAL  \
# 0            ...                        0            1              1
# 1            ...                        0            1              1
# 2            ...                        0            1              2
# 3            ...                        1            1              1
# 4            ...                        0            1              2
#
#   LOAN_NUM_CLOSED LOAN_NUM_PAYM LOAN_DLQ_NUM LOAN_MAX_DLQ  LOAN_AVG_DLQ_AMT  \
# 0               1             6            2            1              1580
# 1               1             6            1            1              4020
# 2               1            11            0            0                 0
# 3               1             6            3            1  1589,92333333333
# 4               1            16            2            1           1152,15
#
#   LOAN_MAX_DLQ_AMT PREVIOUS_CARD_NUM_UTILIZED
# 0             1580                        NaN
# 1             4020                        NaN
# 2                0                        NaN
# 3             1590                        NaN
# 4             2230                        NaN
#
# [5 rows x 52 columns]

# %% [markdown]
# ## Объединим две выборки
#
# Так как пока мы пока не умеем работать sklearn  Pipeline, то для того, чтобы после предобработки столбцы в двух выборках находились на своих местах.
#
# Для того, чтобы в дальнейшем отделить их введем новый столбец "sample"

# %%
df_train.loc[:, 'sample'] = 'train'
df_test.loc[:, 'sample'] = 'test'

# %%
df = df_test.append(df_train).reset_index(drop=True)

# %%
df.shape
# Out:
# (30133, 53)

# %% [markdown]
# ### Чуть-чуть посмотрим на данные

# %% [markdown]
# Посмотрим типы данных и их заполняемость

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30133 entries, 0 to 30132
# Data columns (total 53 columns):
# AGREEMENT_RK                  30133 non-null int64
# TARGET                        30133 non-null int64
# AGE                           30133 non-null int64
# SOCSTATUS_WORK_FL             30133 non-null int64
# SOCSTATUS_PENS_FL             30133 non-null int64
# GENDER                        30133 non-null int64
# CHILD_TOTAL                   30133 non-null int64
# DEPENDANTS                    30133 non-null int64
# EDUCATION                     30133 non-null object
# MARITAL_STATUS                30133 non-null object
# GEN_INDUSTRY                  27420 non-null object
# GEN_TITLE                     27420 non-null object
# ORG_TP_STATE                  27420 non-null object
# ORG_TP_FCAPITAL               27425 non-null object
# JOB_DIR                       27420 non-null object
# FAMILY_INCOME                 30133 non-null object
# PERSONAL_INCOME               30133 non-null object
# REG_ADDRESS_PROVINCE          30133 non-null object
# FACT_ADDRESS_PROVINCE         30133 non-null object
# POSTAL_ADDRESS_PROVINCE       30133 non-null object
# TP_PROVINCE                   29543 non-null object
# REGION_NM                     30131 non-null object
# REG_FACT_FL                   30133 non-null int64
# FACT_POST_FL                  30133 non-null int64
# REG_POST_FL                   30133 non-null int64
# REG_FACT_POST_FL              30133 non-null int64
# REG_FACT_POST_TP_FL           30133 non-null int64
# FL_PRESENCE_FL                30133 non-null int64
# OWN_AUTO                      30133 non-null int64
# AUTO_RUS_FL                   30133 non-null int64
# HS_PRESENCE_FL                30133 non-null int64
# COT_PRESENCE_FL               30133 non-null int64
# GAR_PRESENCE_FL               30133 non-null int64
# LAND_PRESENCE_FL              30133 non-null int64
# CREDIT                        30133 non-null object
# TERM                          30133 non-null int64
# FST_PAYMENT                   30133 non-null object
# DL_DOCUMENT_FL                30133 non-null int64
# GPF_DOCUMENT_FL               30133 non-null int64
# FACT_LIVING_TERM              30133 non-null int64
# WORK_TIME                     27416 non-null float64
# FACT_PHONE_FL                 30133 non-null int64
# REG_PHONE_FL                  30133 non-null int64
# GEN_PHONE_FL                  30133 non-null int64
# LOAN_NUM_TOTAL                30133 non-null int64
# LOAN_NUM_CLOSED               30133 non-null int64
# LOAN_NUM_PAYM                 30133 non-null int64
# LOAN_DLQ_NUM                  30133 non-null int64
# LOAN_MAX_DLQ                  30133 non-null int64
# LOAN_AVG_DLQ_AMT              30133 non-null object
# LOAN_MAX_DLQ_AMT              30133 non-null object
# PREVIOUS_CARD_NUM_UTILIZED    600 non-null float64
# sample                        30133 non-null object
# dtypes: float64(2), int64(32), object(19)
# memory usage: 12.2+ MB

# %% [markdown]
# Видим, что часть данных - object, скорее всего стоки.
#
#
# Давайте выведем эти значения для каждого столбца

# %%
for i in df_train.columns: # перебираем все столбцы
    if str(df_train[i].dtype) == 'object': # если тип столбца - object
        print('='*10)
        print(i) # выводим название столбца
        print(set(df_train[i])) # выводим все его значения (но делаем set - чтоб значения не повторялись)
        print('\n') # выводим пустую строку
# Out:
# ==========
# EDUCATION
# {'Ученая степень', 'Два и более высших образования', 'Среднее специальное', 'Неоконченное высшее', 'Среднее', 'Высшее', 'Неполное среднее'}
#
#
# ==========
# MARITAL_STATUS
# {'Состою в браке', 'Гражданский брак', 'Разведен(а)', 'Вдовец/Вдова', 'Не состоял в браке'}
#
#
# ==========
# GEN_INDUSTRY
# {nan, 'Образование', 'Информационные услуги', 'Логистика', 'Подбор персонала', 'Банк/Финансы', 'Страхование', 'Нефтегазовая промышленность', 'Наука', 'Юридические услуги/нотариальные услуги', 'Химия/Парфюмерия/Фармацевтика', 'СМИ/Реклама/PR-агенства', 'Недвижимость', 'Сельское хозяйство', 'Информационные технологии', 'Здравоохранение', 'ЧОП/Детективная д-ть', 'Коммунальное хоз-во/Дорожные службы', 'Развлечения/Искусство', 'Торговля', 'Другие сферы', 'Металлургия/Промышленность/Машиностроение', 'Туризм', 'Маркетинг', 'Салоны красоты и здоровья', 'Транспорт', 'Управляющая компания', 'Ресторанный бизнес/Общественное питание', 'Энергетика', 'Государственная служба', 'Сборочные производства', 'Строительство'}
#
#
# ==========
# GEN_TITLE
# {'Специалист', 'Служащий', nan, 'Руководитель высшего звена', 'Партнер', 'Руководитель среднего звена', 'Индивидуальный предприниматель', 'Другое', 'Высококвалифиц. специалист', 'Военнослужащий по контракту', 'Работник сферы услуг', 'Руководитель низшего звена', 'Рабочий'}
#
#
# ==========
# ORG_TP_STATE
# {nan, 'Частная ком. с инос. капиталом', 'Индивидуальный предприниматель', 'Частная компания', 'Некоммерческая организация', 'Государственная комп./учреж.'}
#
#
# ==========
# ORG_TP_FCAPITAL
# {nan, 'С участием', 'Без участия'}
#
#
# ==========
# JOB_DIR
# {nan, 'Реклама и маркетинг', 'Пр-техн. обесп. и телеком.', 'Адм-хоз. и трансп. службы', 'Служба безопасности', 'Юридическая служба', 'Бухгалтерия, финансы, планир.', 'Снабжение и сбыт', 'Вспомогательный техперсонал', 'Кадровая служба и секретариат', 'Участие в основ. деятельности'}
#
#
# ==========
# FAMILY_INCOME
# {'от 5000 до 10000 руб.', 'до 5000 руб.', 'от 10000 до 20000 руб.', 'от 20000 до 50000 руб.', 'свыше 50000 руб.'}
#
#
# ==========
# PERSONAL_INCOME
# {'67700', '13200', '8726', '13400', '31000', '42500', '11400', '17000', '7900', '9240', '23000', '16900', '92000', '8200', '4340', '11200', '51000', '6608', '9900', '10100', '8000', '5000', '7050', '6300', '27300', '6359', '23800', '8350', '4300', '13000', '110000', '12900', '9300', '21000', '13500', '16000', '27000', '9500', '4600', '68000', '22000', '7250', '19500', '12400', '38000', '16700', '6670', '26500', '2300', '6800', '11640', '3300', '12800', '42000', '21500', '50000', '12700', '4400', '7101', '52000', '15600', '12300', '15380', '5700', '9330', '7550', '22955', '9000', '41000', '9800', '7251', '5400', '16500', '8900', '5350', '4800', '75000', '5050', '10400', '29800', '13900', '10900', '28300', '5460', '5680', '5100', '7220', '7700', '9628', '12000', '5360', '11500', '17800', '7650', '9600', '11800', '60000', '15200', '11000', '16050', '2800', '14500', '29500', '7200', '6299,19', '23500', '47000', '18500', '20500', '5200', '17200', '10700', '10500', '9340', '48000', '24500', '6000', '14358', '6100', '25000', '12600', '80000', '5790', '43000', '17500', '18600', '13160', '7640', '5339', '56000', '13450', '8100', '18200', '3800', '3100', '19800', '3400', '53000', '3200', '21800', '2000', '25800', '34000', '15500', '6180', '9400', '8250', '7300', '18700', '7830', '15400', '5446', '11600', '17900', '77000', '10200', '12650', '67000', '7100', '3000', '5300', '8066', '41900', '17404', '35000', '13150', '12500', '8400', '26000', '4200', '20000', '9100', '37000', '13300', '15560', '8600', '16100', '13800', '32000', '8800', '4360', '16200', '22500', '46000', '4590', '8500', '5582', '44000', '11300', '15000', '5600', '32640', '14700', '13700', '19600', '65000', '250000', '4950', '5425', '6600', '7800', '10800', '5900', '17600', '6700', '19700', '20646,16', '17700', '14000', '8700', '14300', '7000', '39000', '4330', '11900', '29000', '2100', '9200', '49000', '15300', '160000', '55000', '10000', '170000', '24800', '5800', '13600', '220000', '12100', '23100', '3500', '5230', '14800', '4900', '19300', '3700', '9700', '19000', '4100', '7850', '33000', '6900', '5088', '4700', '6400', '45000', '7400', '18000', '10300', '150000', '54000', '16800', '6200', '4000', '7600', '10600', '3900', '7500', '36000', '3600', '28000', '24000', '24', '6500', '11700', '4500', '100000', '4515', '8300', '1950', '5500', '70000', '40000', '30000'}
#
#
# ==========
# REG_ADDRESS_PROVINCE
# {'Ямало-Ненецкий АО', 'Саратовская область', 'Московская область', 'Орловская область', 'Астраханская область', 'Тверская область', 'Курганская область', 'Бурятия', 'Новгородская область', 'Пермская область', 'Северная Осетия', 'Калмыкия', 'Омская область', 'Белгородская область', 'Псковская область', 'Эвенкийский АО', 'Москва', 'Ленинградская область', 'Кемеровская область', 'Камчатская область', 'Карелия', 'Марийская республика', 'Краснодарский край', 'Воронежская область', 'Читинская область', 'Дагестан', 'Агинский Бурятский АО', 'Татарстан', 'Смоленская область', 'Адыгея', 'Самарская область', 'Курская область', 'Пензенская область', 'Владимирская область', 'Карачаево-Черкесия', 'Волгоградская область', 'Сахалинская область', 'Красноярский край', 'Костромская область', 'Нижегородская область', 'Челябинская область', 'Чувашия', 'Калининградская область', 'Тюменская область', 'Оренбургская область', 'Вологодская область', 'Иркутская область', 'Ростовская область', 'Башкирия', 'Мордовская республика', 'Ханты-Мансийский АО', 'Тамбовская область', 'Хабаровский край', 'Кировская область', 'Свердловская область', 'Магаданская область', 'Алтайский край', 'Архангельская область', 'Ставропольский край', 'Коми', 'Томская область', 'Горный Алтай', 'Тульская область', 'Ярославская область', 'Липецкая область', 'Ульяновская область', 'Кабардино-Балкария', 'Ивановская область', 'Мурманская область', 'Рязанская область', 'Хакасия', 'Брянская область', 'Усть-Ордынский Бурятский АО', 'Удмуртия', 'Санкт-Петербург', 'Приморский край', 'Якутия', 'Амурская область', 'Новосибирская область', 'Калужская область', 'Еврейская АО'}
#
#
# ==========
# FACT_ADDRESS_PROVINCE
# {'Ямало-Ненецкий АО', 'Саратовская область', 'Московская область', 'Орловская область', 'Астраханская область', 'Тверская область', 'Курганская область', 'Бурятия', 'Новгородская область', 'Пермская область', 'Северная Осетия', 'Калмыкия', 'Омская область', 'Белгородская область', 'Псковская область', 'Эвенкийский АО', 'Москва', 'Ленинградская область', 'Кемеровская область', 'Камчатская область', 'Карелия', 'Марийская республика', 'Краснодарский край', 'Воронежская область', 'Читинская область', 'Агинский Бурятский АО', 'Дагестан', 'Татарстан', 'Смоленская область', 'Адыгея', 'Самарская область', 'Курская область', 'Пензенская область', 'Владимирская область', 'Карачаево-Черкесия', 'Волгоградская область', 'Сахалинская область', 'Красноярский край', 'Костромская область', 'Нижегородская область', 'Челябинская область', 'Чувашия', 'Калининградская область', 'Тюменская область', 'Оренбургская область', 'Вологодская область', 'Иркутская область', 'Ростовская область', 'Башкирия', 'Мордовская республика', 'Ханты-Мансийский АО', 'Тамбовская область', 'Хабаровский край', 'Кировская область', 'Свердловская область', 'Магаданская область', 'Алтайский край', 'Архангельская область', 'Ставропольский край', 'Коми', 'Томская область', 'Горный Алтай', 'Тульская область', 'Ярославская область', 'Липецкая область', 'Ульяновская область', 'Кабардино-Балкария', 'Ивановская область', 'Мурманская область', 'Рязанская область', 'Хакасия', 'Брянская область', 'Усть-Ордынский Бурятский АО', 'Удмуртия', 'Санкт-Петербург', 'Приморский край', 'Якутия', 'Амурская область', 'Новосибирская область', 'Калужская область', 'Еврейская АО'}
#
#
# ==========
# POSTAL_ADDRESS_PROVINCE
# {'Ямало-Ненецкий АО', 'Саратовская область', 'Московская область', 'Орловская область', 'Астраханская область', 'Тверская область', 'Курганская область', 'Бурятия', 'Новгородская область', 'Пермская область', 'Северная Осетия', 'Калмыкия', 'Омская область', 'Белгородская область', 'Псковская область', 'Эвенкийский АО', 'Москва', 'Ленинградская область', 'Кемеровская область', 'Камчатская область', 'Карелия', 'Марийская республика', 'Краснодарский край', 'Воронежская область', 'Читинская область', 'Агинский Бурятский АО', 'Татарстан', 'Смоленская область', 'Адыгея', 'Самарская область', 'Курская область', 'Пензенская область', 'Владимирская область', 'Карачаево-Черкесия', 'Волгоградская область', 'Сахалинская область', 'Красноярский край', 'Костромская область', 'Нижегородская область', 'Челябинская область', 'Чувашия', 'Калининградская область', 'Тюменская область', 'Оренбургская область', 'Вологодская область', 'Иркутская область', 'Ростовская область', 'Башкирия', 'Мордовская республика', 'Ханты-Мансийский АО', 'Тамбовская область', 'Хабаровский край', 'Кировская область', 'Свердловская область', 'Магаданская область', 'Алтайский край', 'Архангельская область', 'Ставропольский край', 'Коми', 'Томская область', 'Горный Алтай', 'Тульская область', 'Ярославская область', 'Липецкая область', 'Ульяновская область', 'Кабардино-Балкария', 'Ивановская область', 'Мурманская область', 'Рязанская область', 'Хакасия', 'Брянская область', 'Усть-Ордынский Бурятский АО', 'Удмуртия', 'Санкт-Петербург', 'Приморский край', 'Якутия', 'Амурская область', 'Новосибирская область', 'Калужская область', 'Еврейская АО'}
#
#
# ==========
# TP_PROVINCE
# {nan, 'Саратовская область', 'Орловская область', 'Астраханская область', 'Тверская область', 'Курганская область', 'Бурятия', 'Новгородская область', 'Пермская область', 'Омская область', 'Белгородская область', 'Псковская область', 'Москва', 'Кемеровская область', 'Камчатская область', 'Карелия', 'Марийская республика', 'Краснодарский край', 'Воронежская область', 'Читинская область', 'Татарстан', 'Смоленская область', 'Адыгея', 'Самарская область', 'Курская область', 'Пензенская область', 'Владимирская область', 'Волгоградская область', 'Сахалинская область', 'Красноярский край', 'Костромская область', 'Нижегородская область', 'Челябинская область', 'Чувашия', 'Калининградская область', 'Тюменская область', 'Оренбургская область', 'Вологодская область', 'Иркутская область', 'Ростовская область', 'Башкирия', 'Мордовская республика', 'Ханты-Мансийский АО', 'Тамбовская область', 'Хабаровский край', 'Кировская область', 'Свердловская область', 'Магаданская область', 'Алтайский край', 'Архангельская область', 'Ставропольский край', 'Коми', 'Томская область', 'Горный Алтай', 'Тульская область', 'Ярославская область', 'Липецкая область', 'Ульяновская область', 'Рязанская область', 'Ивановская область', 'Мурманская область', 'Кабардино-Балкария', 'Брянская область', 'Удмуртия', 'Санкт-Петербург', 'Приморский край', 'Якутия', 'Амурская область', 'Новосибирская область', 'Калужская область', 'Еврейская АО'}
#
#
# ==========
# REGION_NM
# {'ДАЛЬНЕВОСТОЧНЫЙ', nan, 'СЕВЕРО-ЗАПАДНЫЙ', 'ЮЖНЫЙ', 'ПРИВОЛЖСКИЙ', 'ВОСТОЧНО-СИБИРСКИЙ', 'ЦЕНТРАЛЬНЫЙ 2', 'ЗАПАДНО-СИБИРСКИЙ', 'ЦЕНТРАЛЬНЫЙ 1', 'УРАЛЬСКИЙ', 'ПОВОЛЖСКИЙ', 'ЦЕНТРАЛЬНЫЙ ОФИС'}
#
#
# ==========
# CREDIT
# {'21060', '13200', '9876', '8117', '60500', '13137', '6580', '87600', '9789', '3961', '4945', '6246', '27493', '17930', '26370', '8970', '4674', '16715', '25695', '4563', '14204', '8606', '11898', '3090', '26690', '29075', '4175', '23347', '20343', '5350', '4315', '14765', '3768', '10348', '13193', '61250', '7874', '15800', '8694', '16455', '7860', '18318', '4191', '10665', '10930,52', '17605', '11363,99', '5989', '28350', '10680', '29615', '5219', '18615', '16830', '33850', '13940', '12646', '2819', '16899', '20698', '10550', '11510', '33320', '8184', '25623', '21300', '10820', '12317', '3894,2', '42689', '12716', '7869,61', '3000', '3580', '10910,6', '50879,83', '4479', '24502', '15460', '3061,45', '19360', '4730', '3339', '7965', '21482', '12541', '28722', '26049', '14440', '25180', '8099', '2850', '12570', '13649', '2000,51', '6504', '2072,7', '17106', '10435', '7998', '27020', '7581', '10058,5', '18445', '12060', '21915', '7107', '14388,3', '8603', '27196,1', '5589', '6500', '11571', '7769', '35900', '12514', '35550', '27740', '6789', '22091', '11315', '3599', '4647', '28861', '69000', '6301', '5149', '27895', '8544', '19734', '8549', '6499', '28933', '8564', '4949', '12616', '10631', '21286', '16870', '18225', '21154', '12265', '32970', '4858', '5516', '23930', '27449', '18096', '35955', '4890', '3545', '24059,83', '14257,91', '26280', '14199', '10381,5', '10529', '9061', '4964', '22299', '5384', '6950,7', '23539', '12919', '50568', '24420', '9990,91', '5715', '9540', '13402', '3099', '7191', '4653', '14678', '42
...
#
#
# ==========
# sample
# {'train'}

# %% [markdown]
# Mожно заметить что некоторые переменные, которые обозначены как строки (например PERSONAL_INCOME) на самом деле числа, но по какой-то причине были распознаны как строки
#
# Причина же что использовалась запятая для разделения не целой части числа..

# %% [markdown]
# Перекодировать их можно например так:

# %%
df['PERSONAL_INCOME'].map(lambda x: x.replace(',', '.')).astype('float')
# Out:
# 0         7000.0
# 1         4100.0
# 2        40000.0
# 3        20000.0
# 4        17000.0
# 5         7000.0
# 6        10000.0
# 7         7500.0
# 8         9000.0
# 9         4000.0
# 10       15000.0
# 11       12000.0
# 12        8000.0
# 13       20000.0
# 14       18500.0
# 15       14000.0
# 16        6000.0
# 17        9000.0
# 18        5000.0
# 19       15000.0
# 20        6100.0
# 21       22180.0
# 22        9000.0
# 23        8700.0
# 24        7000.0
# 25        6000.0
# 26       15000.0
# 27       12000.0
# 28       11000.0
# 29        8000.0
#           ...
# 30103    12000.0
# 30104    10000.0
# 30105    10000.0
# 30106     8000.0
# 30107    11000.0
# 30108     7000.0
# 30109    10000.0
# 30110     8000.0
# 30111    25000.0
# 30112    10000.0
# 30113    12000.0
# 30114     7000.0
# 30115    12000.0
# 30116    14500.0
# 30117    12000.0
# 30118     8000.0
# 30119     7000.0
# 30120    10000.0
# 30121    10000.0
# 30122    10000.0
# 30123    15000.0
# 30124     8100.0
# 30125     9500.0
# 30126    13000.0
# 30127    10000.0
# 30128    12000.0
# 30129    10000.0
# 30130     6000.0
# 30131     4500.0
# 30132    20000.0
# Name: PERSONAL_INCOME, Length: 30133, dtype: float64

# %% [markdown]
# Такой эффект наблюдается в столбцах `PERSONAL_INCOME`, `CREDIT`, `FST_PAYMENT`, `LOAN_AVG_DLQ_AMT`, `LOAN_MAX_DLQ_AMT`

# %% [markdown]
# ### Теперь ваше небольшое исследование

# %% [markdown]
# #### Задание 1. Есть ли пропуски в данных? Что с ними сделать?
#
# (единственного верного ответа нет - аргументируйте)

# %%
#В зависимости от задачи - заполнить пропуски нулями, единицами, средним или медианой. 
#Также можно удалить столбец с пропусками или удалить строки с пропусками.

# %% [markdown]
# #### Задание 2. Есть ли категориальные признаки? Что с ними делать?

# %%
#Можно закодировать категории цифрами 1,2,3, но тогда категории будут не равнозначны. 
#Или добавить новые столбцы по числу категорий, в которые записывать 1, если столбец 
#соответствует признаку, присущему данной сущности и 0, если не соответствует.

# %% [markdown]
# #### Задание 3. Фунция предобработки

# %% [markdown]
# Напишите функцию, которая бы
#
# * Удаляло идентификатор `AGREEMENT_RK`
# * Избавлялась от проблем с '.' и ',' в стобцах PERSONAL_INCOME, CREDIT, FST_PAYMENT, LOAN_AVG_DLQ_AMT, LOAN_MAX_DLQ_AMT
# * Что-то делала с пропусками
# * Кодировала категориальные признаки
#
# В результате, ваш датафрейм должен содержать только числа и не содержать пропусков!

# %%
def preproc_data(df_input):
    df_output = df_input.copy()
    
    df_output = df_output.drop(['AGREEMENT_RK'], axis=1)
    
    df_output['PERSONAL_INCOME']=df_output['PERSONAL_INCOME'].map(lambda x: x.replace(',', '.')).astype('float')
    df_output['CREDIT']=df_output['CREDIT'].map(lambda x: x.replace(',', '.')).astype('float')
    df_output['FST_PAYMENT']=df_output['FST_PAYMENT'].map(lambda x: x.replace(',', '.')).astype('float')
    df_output['LOAN_AVG_DLQ_AMT']=df_output['LOAN_AVG_DLQ_AMT'].map(lambda x: x.replace(',', '.')).astype('float')
    df_output['LOAN_MAX_DLQ_AMT']=df_output['LOAN_MAX_DLQ_AMT'].map(lambda x: x.replace(',', '.')).astype('float')
    
    #df.Age.fillna(df.Age.mean())
    df_output.WORK_TIME=df_output.WORK_TIME.fillna(df_output.WORK_TIME.mean())
    df_output.PREVIOUS_CARD_NUM_UTILIZED=df_output.PREVIOUS_CARD_NUM_UTILIZED.fillna(0)
    #df_output.WORK_TIME[df_output.WORK_TIME.isnull()] = df_output.WORK_TIME.mean()
    #df_output.PREVIOUS_CARD_NUM_UTILIZED[df_output.PREVIOUS_CARD_NUM_UTILIZED.isnull()] = 0
    #df_output.GEN_INDUSTRY.fillna('не задано')                  
    #df_output.GEN_TITLE.fillna('не задано')                     
    #df_output.ORG_TP_STATE.fillna('не задано')                   
    #df_output.ORG_TP_FCAPITAL.fillna('не задано')                
    #df_output.JOB_DIR.fillna('не задано')         
    #df_output.TP_PROVINCE.fillna('не задано')    
    df_output=pd.get_dummies(df_output,columns=['EDUCATION','MARITAL_STATUS','GEN_INDUSTRY','GEN_TITLE','ORG_TP_STATE','ORG_TP_FCAPITAL','JOB_DIR','FAMILY_INCOME','REG_ADDRESS_PROVINCE','FACT_ADDRESS_PROVINCE','POSTAL_ADDRESS_PROVINCE','TP_PROVINCE','REGION_NM'])    
    return df_output
df_preproc = df.pipe(preproc_data)
#abv=df_preproc.head()
#abv.T
df_preproc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30133 entries, 0 to 30132
# Columns: 444 entries, TARGET to REGION_NM_ЮЖНЫЙ
# dtypes: float64(7), int64(31), object(1), uint8(405)
# memory usage: 20.6+ MB

# %%
df_preproc = df.pipe(preproc_data)

df_train_preproc = df_preproc.query('sample == "train"').drop(['sample'], axis=1)
df_test_preproc = df_preproc.query('sample == "test"').drop(['sample'], axis=1)

# %% [markdown]
# #### Задание 4. Отделите целевую переменную и остальные признаки
#
# Должно получится:
# * 2 матрицы: X и X_test
# * 2 вектора: y и y_test

# %%
from sklearn.cross_validation import train_test_split
y=df_preproc['TARGET']
df_preproc = df_preproc.drop(['TARGET'], axis=1)
X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.3, random_state=42)

# %% [markdown]
# #### Задание 5. Обучение и оценка качества разных моделей

# %%
#from sklearn.cross_validation import train_test_split
# test_size=0.3, random_state=42

#X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.3, random_state=42)
y_train=df_train_preproc['TARGET']
df_train_preproc = df_train_preproc.drop(['TARGET'], axis=1)

# %%
y_test=df_test_preproc['TARGET']
df_test_preproc = df_test_preproc.drop(['TARGET'], axis=1)

# %%
df_train_preproc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15223 entries, 14910 to 30132
# Columns: 442 entries, AGE to REGION_NM_ЮЖНЫЙ
# dtypes: float64(7), int64(30), uint8(405)
# memory usage: 10.3 MB

# %%
# Попробовать следующие "черные ящики": интерфейс одинаковый 
#     fit, 
#     predict, 
#     predict_proba

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

## Your Code Here

dtc = DecisionTreeClassifier()
dtc.fit(df_train_preproc, y_train)
predict = dtc.predict(df_test_preproc)

# %%
# Посчитать метрики стандартные
# accuracy, precision, recall

from sklearn.metrics import accuracy_score, precision_score, recall_score

print('precision', precision_score(y_test, predict))
print('recall', recall_score(y_test, predict))
print('accuracy', accuracy_score(y_test, predict))
# Out:
# precision 0.1668496158068057
# recall 0.1737142857142857
# accuracy 0.8012072434607646

# %%
recall_score(y_test, predict)
# Out:
# 0.1737142857142857

# %%
# Визуалищировать эти метрики всех моделей на одном графике (чтоб визуально посмотреть)

## Your Code Here

# %%
# Потроить roc-кривые всех можелей на одном графике
# Вывести roc_auc каждой моделе

## Your Code Here

# %%
from sklearn.cross_validation import cross_val_score
from sklearn.model_selection import StratifiedKFold
# Сделать k-fold (10 фолдов) кросс-валидацию каждой модели
# И посчитать средний roc_auc
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=123)

## Your Code Here

# %%
# Взять лучшую модель и сделать predict (с вероятностями (!!!)) для test выборки


## Your Code Here

# %%
# Померить roc_auc на тесте
