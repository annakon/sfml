# %% [markdown]
# # SkillFactory
# ## Введение в ML, введение в sklearn

# %% [markdown]
# В этом задании мы с вами рассмотрим данные с конкурса [Задача предсказания отклика клиентов ОТП Банка](http://www.machinelearning.ru/wiki/index.php?title=%D0%97%D0%B0%D0%B4%D0%B0%D1%87%D0%B0_%D0%BF%D1%80%D0%B5%D0%B4%D1%81%D0%BA%D0%B0%D0%B7%D0%B0%D0%BD%D0%B8%D1%8F_%D0%BE%D1%82%D0%BA%D0%BB%D0%B8%D0%BA%D0%B0_%D0%BA%D0%BB%D0%B8%D0%B5%D0%BD%D1%82%D0%BE%D0%B2_%D0%9E%D0%A2%D0%9F_%D0%91%D0%B0%D0%BD%D0%BA%D0%B0_%28%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%29)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12,5)

# %% [markdown]
# ### Грузим данные

# %% [markdown]
# Считаем описание данных

# %%
df_descr = pd.read_csv('data/otp_description.csv', sep='\t', encoding='utf8')

# %%
df_descr
# Out:
#                           ПОЛЕ  \
# 0                 AGREEMENT_RK
# 1                          AGE
# 2            SOCSTATUS_WORK_FL
# 3            SOCSTATUS_PENS_FL
# 4                       GENDER
# 5                  CHILD_TOTAL
# 6                   DEPENDANTS
# 7                    EDUCATION
# 8               MARITAL_STATUS
# 9                 GEN_INDUSTRY
# 10                   GEN_TITLE
# 11                ORG_TP_STATE
# 12             ORG_TP_FCAPITAL
# 13                     JOB_DIR
# 14               FAMILY_INCOME
# 15             PERSONAL_INCOME
# 16        REG_ADDRESS_PROVINCE
# 17       FACT_ADDRESS_PROVINCE
# 18     POSTAL_ADDRESS_PROVINCE
# 19                 TP_PROVINCE
# 20                   REGION_NM
# 21                 REG_FACT_FL
# 22                FACT_POST_FL
# 23                 REG_POST_FL
# 24            REG_FACT_POST_FL
# 25         REG_FACT_POST_TP_FL
# 26              FL_PRESENCE_FL
# 27                    OWN_AUTO
# 28                 AUTO_RUS_FL
# 29              HS_PRESENCE_FL
# 30             COT_PRESENCE_FL
# 31             GAR_PRESENCE_FL
# 32            LAND_PRESENCE_FL
# 33                      CREDIT
# 34                        TERM
# 35                 FST_PAYMENT
# 36              DL_DOCUMENT_FL
# 37             GPF_DOCUMENT_FL
# 38            FACT_LIVING_TERM
# 39                   WORK_TIME
# 40               FACT_PHONE_FL
# 41                REG_PHONE_FL
# 42                GEN_PHONE_FL
# 43              LOAN_NUM_TOTAL
# 44             LOAN_NUM_CLOSED
# 45               LOAN_NUM_PAYM
# 46                LOAN_DLQ_NUM
# 47                LOAN_MAX_DLQ
# 48            LOAN_AVG_DLQ_AMT
# 49            LOAN_MAX_DLQ_AMT
# 50  PREVIOUS_CARD_NUM_UTILIZED
#
#                                              ОПИСАНИЕ
# 0          уникальный идентификатор объекта в выборке
# 1                                     возраст клиента
# 2   социальный статус клиента относительно работы ...
# 3   социальный статус клиента относительно пенсии ...
# 4                 пол клиента (1- женщины, 0-мужчины)
# 5                            количество детей клиента
# 6                       количество иждивенцев клиента
# 7                                         образование
# 8                                  семейное положение
# 9                              отрасль работы клиента
# 10                                          должность
# 11                       форма собственности компании
# 12                  отношение к иностранному капиталу
# 13          направление деятельности в нутри компании
# 14               семейный доход (несколько категорий)
# 15                    личный доход клиента (в рублях)
# 16                        область регистрации клиента
# 17            область фактического пребывания клиента
# 18                             почтовый адрес область
# 19  область торговой точки, где клиент брал послед...
# 20                                          регион РФ
# 21  адрес регистрации и адрес фактического пребыва...
# 22  адрес фактического пребывания клиента и его по...
# 23  адрес регистрации клиента и его почтовый адрес...
# 24  почтовый, фактический и адрес регистрации совп...
# 25  область регистрации, фактического пребывания, ...
# 26  наличие в собственности квартиры (1 - есть, 0 ...
# 27                кол-во автомобилей в собственности
# 28  наличие в собственности автомобиля российского...
# 29  наличие в собственности загородного дома (1 - ...
# 30  наличие в собственности котеджа (1 - есть, 0 -...
# 31  наличие в собственности гаража (1 - есть, 0 - ...
# 32  наличие в собственности земельного участка (1 ...
# 33        сумма последнего кредита клиента (в рублях)
# 34                                       срок кредита
# 35                    первоначальный взнос (в рублях)
# 36  в анкете клиент указал водительское удостовере...
# 37  в анкете клиен указал ГПФ (1 - указал, 0 - не ...
# 38  количество месяцев проживания по месту фактиче...
# 39          время работы на текущем месте (в месяцах)
# 40  наличие в заявке телефона по фактическому мест...
# 41     наличие в заявке телефона по месту регистрации
# 42                 наличие в заявке рабочего телефона
# 43                            количество ссуд клиента
# 44                 количество погашенных ссуд клиента
# 45         количество платежей, которые сделал клиент
# 46          количество просрочек, допущенных клиентом
# 47  номер максимальной просрочки, допущенной клиентом
# 48                 средняя сумма просрочки (в рублях)
# 49            максимальная сумма просрочки (в рублях)
# 50  количество уже утилизированных карт ( если пус...

# %% [markdown]
# Считаем обучающую выборки и тестовую (которую мы как бы не видим)

# %%
df_train = pd.read_csv('data/otp_train.csv', sep='\t', encoding='utf8')

# %%
df_train.shape
# Out:
# (15223, 52)

# %%
df_test = pd.read_csv('data/otp_test.csv', sep='\t', encoding='utf8')

# %%
df_test.shape
# Out:
# (14910, 52)

# %%
df_train.head()
# Out:
#    AGREEMENT_RK  TARGET  AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  GENDER  \
# 0      59910150       0   49                  1                  0       1
# 1      59910230       0   32                  1                  0       1
# 2      59910525       0   52                  1                  0       1
# 3      59910803       0   39                  1                  0       1
# 4      59911781       0   30                  1                  0       0
#
#    CHILD_TOTAL  DEPENDANTS            EDUCATION  MARITAL_STATUS  \
# 0            2           1  Среднее специальное  Состою в браке
# 1            3           3              Среднее  Состою в браке
# 2            4           0     Неполное среднее  Состою в браке
# 3            1           1               Высшее  Состою в браке
# 4            0           0              Среднее  Состою в браке
#
#              ...             REG_PHONE_FL GEN_PHONE_FL LOAN_NUM_TOTAL  \
# 0            ...                        0            1              1
# 1            ...                        0            1              1
# 2            ...                        0            1              2
# 3            ...                        1            1              1
# 4            ...                        0            1              2
#
#   LOAN_NUM_CLOSED LOAN_NUM_PAYM LOAN_DLQ_NUM LOAN_MAX_DLQ  LOAN_AVG_DLQ_AMT  \
# 0               1             6            2            1              1580
# 1               1             6            1            1              4020
# 2               1            11            0            0                 0
# 3               1             6            3            1  1589,92333333333
# 4               1            16            2            1           1152,15
#
#   LOAN_MAX_DLQ_AMT PREVIOUS_CARD_NUM_UTILIZED
# 0             1580                        NaN
# 1             4020                        NaN
# 2                0                        NaN
# 3             1590                        NaN
# 4             2230                        NaN
#
# [5 rows x 52 columns]

# %% [markdown]
# ## Объединим две выборки
#
# Так как пока мы пока не умеем работать sklearn  Pipeline, то для того, чтобы после предобработки столбцы в двух выборках находились на своих местах.
#
# Для того, чтобы в дальнейшем отделить их введем новый столбец "sample"

# %%
df_train.loc[:, 'sample'] = 'train'
df_test.loc[:, 'sample'] = 'test'

# %%
df = df_test.append(df_train).reset_index(drop=True)

# %%
df.shape
# Out:
# (30133, 53)

# %% [markdown]
# ### Чуть-чуть посмотрим на данные

# %% [markdown]
# Посмотрим типы данных и их заполняемость

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30133 entries, 0 to 30132
# Data columns (total 53 columns):
# AGREEMENT_RK                  30133 non-null int64
# TARGET                        30133 non-null int64
# AGE                           30133 non-null int64
# SOCSTATUS_WORK_FL             30133 non-null int64
# SOCSTATUS_PENS_FL             30133 non-null int64
# GENDER                        30133 non-null int64
# CHILD_TOTAL                   30133 non-null int64
# DEPENDANTS                    30133 non-null int64
# EDUCATION                     30133 non-null object
# MARITAL_STATUS                30133 non-null object
# GEN_INDUSTRY                  27420 non-null object
# GEN_TITLE                     27420 non-null object
# ORG_TP_STATE                  27420 non-null object
# ORG_TP_FCAPITAL               27425 non-null object
# JOB_DIR                       27420 non-null object
# FAMILY_INCOME                 30133 non-null object
# PERSONAL_INCOME               30133 non-null object
# REG_ADDRESS_PROVINCE          30133 non-null object
# FACT_ADDRESS_PROVINCE         30133 non-null object
# POSTAL_ADDRESS_PROVINCE       30133 non-null object
# TP_PROVINCE                   29543 non-null object
# REGION_NM                     30131 non-null object
# REG_FACT_FL                   30133 non-null int64
# FACT_POST_FL                  30133 non-null int64
# REG_POST_FL                   30133 non-null int64
# REG_FACT_POST_FL              30133 non-null int64
# REG_FACT_POST_TP_FL           30133 non-null int64
# FL_PRESENCE_FL                30133 non-null int64
# OWN_AUTO                      30133 non-null int64
# AUTO_RUS_FL                   30133 non-null int64
# HS_PRESENCE_FL                30133 non-null int64
# COT_PRESENCE_FL               30133 non-null int64
# GAR_PRESENCE_FL               30133 non-null int64
# LAND_PRESENCE_FL              30133 non-null int64
# CREDIT                        30133 non-null object
# TERM                          30133 non-null int64
# FST_PAYMENT                   30133 non-null object
# DL_DOCUMENT_FL                30133 non-null int64
# GPF_DOCUMENT_FL               30133 non-null int64
# FACT_LIVING_TERM              30133 non-null int64
# WORK_TIME                     27416 non-null float64
# FACT_PHONE_FL                 30133 non-null int64
# REG_PHONE_FL                  30133 non-null int64
# GEN_PHONE_FL                  30133 non-null int64
# LOAN_NUM_TOTAL                30133 non-null int64
# LOAN_NUM_CLOSED               30133 non-null int64
# LOAN_NUM_PAYM                 30133 non-null int64
# LOAN_DLQ_NUM                  30133 non-null int64
# LOAN_MAX_DLQ                  30133 non-null int64
# LOAN_AVG_DLQ_AMT              30133 non-null object
# LOAN_MAX_DLQ_AMT              30133 non-null object
# PREVIOUS_CARD_NUM_UTILIZED    600 non-null float64
# sample                        30133 non-null object
# dtypes: float64(2), int64(32), object(19)
# memory usage: 12.2+ MB

# %% [markdown]
# Видим, что часть данных - object, скорее всего стоки.
#
#
# Давайте выведем эти значения для каждого столбца

# %%
for i in df_train.columns: # перебираем все столбцы
    if str(df_train[i].dtype) == 'object': # если тип столбца - object
        print('='*10)
        print(i) # выводим название столбца
        print(set(df_train[i])) # выводим все его значения (но делаем set - чтоб значения не повторялись)
        print('\n') # выводим пустую строку
# Out:
# ==========
# EDUCATION
# {'Высшее', 'Два и более высших образования', 'Ученая степень', 'Неполное среднее', 'Неоконченное высшее', 'Среднее специальное', 'Среднее'}
#
#
# ==========
# MARITAL_STATUS
# {'Вдовец/Вдова', 'Не состоял в браке', 'Гражданский брак', 'Разведен(а)', 'Состою в браке'}
#
#
# ==========
# GEN_INDUSTRY
# {nan, 'Государственная служба', 'Сельское хозяйство', 'Маркетинг', 'Другие сферы', 'Логистика', 'Туризм', 'Транспорт', 'Салоны красоты и здоровья', 'Нефтегазовая промышленность', 'Химия/Парфюмерия/Фармацевтика', 'Подбор персонала', 'Коммунальное хоз-во/Дорожные службы', 'Ресторанный бизнес/Общественное питание', 'Информационные технологии', 'Юридические услуги/нотариальные услуги', 'Здравоохранение', 'СМИ/Реклама/PR-агенства', 'Металлургия/Промышленность/Машиностроение', 'ЧОП/Детективная д-ть', 'Информационные услуги', 'Банк/Финансы', 'Наука', 'Управляющая компания', 'Страхование', 'Строительство', 'Образование', 'Сборочные производства', 'Развлечения/Искусство', 'Недвижимость', 'Энергетика', 'Торговля'}
#
#
# ==========
# GEN_TITLE
# {nan, 'Индивидуальный предприниматель', 'Руководитель низшего звена', 'Специалист', 'Служащий', 'Рабочий', 'Высококвалифиц. специалист', 'Партнер', 'Другое', 'Работник сферы услуг', 'Руководитель высшего звена', 'Военнослужащий по контракту', 'Руководитель среднего звена'}
#
#
# ==========
# ORG_TP_STATE
# {nan, 'Индивидуальный предприниматель', 'Частная компания', 'Государственная комп./учреж.', 'Частная ком. с инос. капиталом', 'Некоммерческая организация'}
#
#
# ==========
# ORG_TP_FCAPITAL
# {'Без участия', nan, 'С участием'}
#
#
# ==========
# JOB_DIR
# {'Служба безопасности', nan, 'Реклама и маркетинг', 'Снабжение и сбыт', 'Юридическая служба', 'Кадровая служба и секретариат', 'Бухгалтерия, финансы, планир.', 'Адм-хоз. и трансп. службы', 'Участие в основ. деятельности', 'Пр-техн. обесп. и телеком.', 'Вспомогательный техперсонал'}
#
#
# ==========
# FAMILY_INCOME
# {'свыше 50000 руб.', 'от 10000 до 20000 руб.', 'от 20000 до 50000 руб.', 'от 5000 до 10000 руб.', 'до 5000 руб.'}
#
#
# ==========
# PERSONAL_INCOME
# {'11000', '22000', '15200', '11400', '7101', '13900', '19000', '3100', '7900', '4700', '5446', '48000', '26000', '7830', '15000', '19500', '3200', '7300', '5582', '60000', '6000', '9900', '13300', '5425', '41900', '11900', '8700', '17200', '6100', '6180', '8600', '50000', '13500', '43000', '3800', '5100', '13700', '9700', '10100', '9240', '9600', '12900', '5230', '3500', '18000', '6600', '7550', '29500', '18700', '52000', '19800', '9200', '10300', '6359', '5050', '7650', '7050', '12500', '5500', '13000', '4800', '14500', '5600', '10900', '5790', '6700', '2100', '56000', '10700', '8726', '8900', '6800', '8800', '19600', '38000', '2000', '7220', '8400', '23500', '17600', '5088', '12000', '20000', '3400', '42500', '7850', '42000', '8500', '9300', '17404', '12400', '3700', '11800', '12600', '4590', '17500', '32640', '5000', '5800', '7250', '9330', '34000', '17700', '11500', '7600', '23800', '150000', '7800', '9500', '21800', '21000', '12100', '22955', '250000', '53000', '4500', '36000', '3600', '24800', '14700', '51000', '47000', '17000', '4300', '11200', '5460', '8066', '54000', '17900', '10000', '7400', '6200', '4900', '3000', '12800', '8300', '5700', '33000', '23100', '13150', '55000', '4340', '6900', '67700', '13160', '92000', '16100', '5360', '27000', '25800', '77000', '13200', '9400', '9628', '15300', '4950', '8200', '18600', '18500', '70000', '170000', '15600', '29800', '16800', '10600', '19300', '24', '2300', '24000', '2800', '8000', '4100', '80000', '5400', '3900', '68000', '160000', '14800', '10800', '5350', '9800', '31000', '28000', '6400', '75000', '13600', '5300', '28300', '12650', '14000', '45000', '6608', '7640', '110000', '12700', '15380', '20500', '7100', '14358', '40000', '39000', '11600', '7700', '3300', '23000', '4600', '8100', '11640', '11700', '10500', '46000', '8350', '9100', '49000', '220000', '65000', '10400', '8250', '7251', '7200', '7500', '26500', '5900', '16200', '9000', '16900', '13450', '6500', '16700', '100000', '41000', '16500', '6299,19', '37000', '27300', '1950', '32000', '6300', '67000', '22500', '12300', '13400', '25000', '4200', '14300', '19700', '4360', '9340', '30000', '21500', '15400', '5339', '4000', '7000', '15500', '15560', '11300', '4330', '18200', '16050', '5200', '16000', '17800', '6670', '5680', '13800', '20646,16', '10200', '35000', '4400', '44000', '29000', '24500', '4515'}
#
#
# ==========
# REG_ADDRESS_PROVINCE
# {'Томская область', 'Новгородская область', 'Владимирская область', 'Амурская область', 'Псковская область', 'Курская область', 'Хакасия', 'Ямало-Ненецкий АО', 'Хабаровский край', 'Тверская область', 'Калининградская область', 'Кемеровская область', 'Орловская область', 'Саратовская область', 'Горный Алтай', 'Адыгея', 'Агинский Бурятский АО', 'Челябинская область', 'Коми', 'Марийская республика', 'Брянская область', 'Камчатская область', 'Ханты-Мансийский АО', 'Астраханская область', 'Чувашия', 'Свердловская область', 'Карачаево-Черкесия', 'Пермская область', 'Ставропольский край', 'Рязанская область', 'Кабардино-Балкария', 'Карелия', 'Мурманская область', 'Краснодарский край', 'Архангельская область', 'Воронежская область', 'Москва', 'Алтайский край', 'Дагестан', 'Тюменская область', 'Красноярский край', 'Тамбовская область', 'Белгородская область', 'Санкт-Петербург', 'Татарстан', 'Якутия', 'Кировская область', 'Курганская область', 'Приморский край', 'Омская область', 'Нижегородская область', 'Северная Осетия', 'Липецкая область', 'Иркутская область', 'Калмыкия', 'Смоленская область', 'Московская область', 'Калужская область', 'Оренбургская область', 'Костромская область', 'Пензенская область', 'Ульяновская область', 'Мордовская республика', 'Ярославская область', 'Удмуртия', 'Еврейская АО', 'Магаданская область', 'Ростовская область', 'Новосибирская область', 'Самарская область', 'Ивановская область', 'Ленинградская область', 'Тульская область', 'Читинская область', 'Сахалинская область', 'Бурятия', 'Вологодская область', 'Башкирия', 'Эвенкийский АО', 'Усть-Ордынский Бурятский АО', 'Волгоградская область'}
#
#
# ==========
# FACT_ADDRESS_PROVINCE
# {'Томская область', 'Новгородская область', 'Владимирская область', 'Амурская область', 'Псковская область', 'Курская область', 'Хакасия', 'Ямало-Ненецкий АО', 'Хабаровский край', 'Тверская область', 'Калининградская область', 'Кемеровская область', 'Орловская область', 'Саратовская область', 'Горный Алтай', 'Адыгея', 'Агинский Бурятский АО', 'Челябинская область', 'Коми', 'Марийская республика', 'Брянская область', 'Камчатская область', 'Ханты-Мансийский АО', 'Астраханская область', 'Чувашия', 'Свердловская область', 'Карачаево-Черкесия', 'Пермская область', 'Ставропольский край', 'Рязанская область', 'Кабардино-Балкария', 'Карелия', 'Мурманская область', 'Краснодарский край', 'Архангельская область', 'Воронежская область', 'Москва', 'Алтайский край', 'Дагестан', 'Тюменская область', 'Красноярский край', 'Тамбовская область', 'Белгородская область', 'Санкт-Петербург', 'Татарстан', 'Якутия', 'Кировская область', 'Курганская область', 'Приморский край', 'Омская область', 'Нижегородская область', 'Северная Осетия', 'Липецкая область', 'Иркутская область', 'Калмыкия', 'Смоленская область', 'Московская область', 'Калужская область', 'Оренбургская область', 'Костромская область', 'Пензенская область', 'Ульяновская область', 'Мордовская республика', 'Ярославская область', 'Удмуртия', 'Еврейская АО', 'Магаданская область', 'Ростовская область', 'Новосибирская область', 'Самарская область', 'Ивановская область', 'Ленинградская область', 'Тульская область', 'Читинская область', 'Сахалинская область', 'Бурятия', 'Вологодская область', 'Башкирия', 'Эвенкийский АО', 'Усть-Ордынский Бурятский АО', 'Волгоградская область'}
#
#
# ==========
# POSTAL_ADDRESS_PROVINCE
# {'Томская область', 'Новгородская область', 'Владимирская область', 'Амурская область', 'Псковская область', 'Курская область', 'Хакасия', 'Ямало-Ненецкий АО', 'Хабаровский край', 'Тверская область', 'Калининградская область', 'Кемеровская область', 'Орловская область', 'Саратовская область', 'Горный Алтай', 'Адыгея', 'Агинский Бурятский АО', 'Челябинская область', 'Коми', 'Марийская республика', 'Брянская область', 'Камчатская область', 'Ханты-Мансийский АО', 'Астраханская область', 'Чувашия', 'Свердловская область', 'Карачаево-Черкесия', 'Пермская область', 'Ставропольский край', 'Рязанская область', 'Кабардино-Балкария', 'Карелия', 'Мурманская область', 'Краснодарский край', 'Архангельская область', 'Воронежская область', 'Москва', 'Алтайский край', 'Тюменская область', 'Красноярский край', 'Тамбовская область', 'Белгородская область', 'Санкт-Петербург', 'Татарстан', 'Якутия', 'Кировская область', 'Курганская область', 'Приморский край', 'Омская область', 'Нижегородская область', 'Северная Осетия', 'Липецкая область', 'Иркутская область', 'Калмыкия', 'Смоленская область', 'Московская область', 'Калужская область', 'Оренбургская область', 'Костромская область', 'Пензенская область', 'Ульяновская область', 'Мордовская республика', 'Ярославская область', 'Удмуртия', 'Еврейская АО', 'Магаданская область', 'Ростовская область', 'Новосибирская область', 'Самарская область', 'Ивановская область', 'Ленинградская область', 'Тульская область', 'Читинская область', 'Сахалинская область', 'Бурятия', 'Вологодская область', 'Башкирия', 'Эвенкийский АО', 'Усть-Ордынский Бурятский АО', 'Волгоградская область'}
#
#
# ==========
# TP_PROVINCE
# {nan, 'Томская область', 'Новгородская область', 'Владимирская область', 'Амурская область', 'Псковская область', 'Курская область', 'Хабаровский край', 'Тверская область', 'Калининградская область', 'Кемеровская область', 'Орловская область', 'Саратовская область', 'Горный Алтай', 'Адыгея', 'Челябинская область', 'Коми', 'Марийская республика', 'Брянская область', 'Камчатская область', 'Ханты-Мансийский АО', 'Астраханская область', 'Чувашия', 'Свердловская область', 'Ставропольский край', 'Пермская область', 'Рязанская область', 'Кабардино-Балкария', 'Карелия', 'Мурманская область', 'Краснодарский край', 'Архангельская область', 'Воронежская область', 'Москва', 'Алтайский край', 'Тюменская область', 'Красноярский край', 'Тамбовская область', 'Белгородская область', 'Санкт-Петербург', 'Татарстан', 'Якутия', 'Кировская область', 'Курганская область', 'Приморский край', 'Омская область', 'Нижегородская область', 'Липецкая область', 'Иркутская область', 'Смоленская область', 'Калужская область', 'Оренбургская область', 'Костромская область', 'Пензенская область', 'Ульяновская область', 'Мордовская республика', 'Ярославская область', 'Удмуртия', 'Еврейская АО', 'Магаданская область', 'Ростовская область', 'Новосибирская область', 'Самарская область', 'Ивановская область', 'Тульская область', 'Читинская область', 'Сахалинская область', 'Бурятия', 'Вологодская область', 'Башкирия', 'Волгоградская область'}
#
#
# ==========
# REGION_NM
# {'СЕВЕРО-ЗАПАДНЫЙ', nan, 'ЦЕНТРАЛЬНЫЙ ОФИС', 'ПОВОЛЖСКИЙ', 'ВОСТОЧНО-СИБИРСКИЙ', 'ЮЖНЫЙ', 'ЦЕНТРАЛЬНЫЙ 2', 'ПРИВОЛЖСКИЙ', 'ЦЕНТРАЛЬНЫЙ 1', 'УРАЛЬСКИЙ', 'ЗАПАДНО-СИБИРСКИЙ', 'ДАЛЬНЕВОСТОЧНЫЙ'}
#
#
# ==========
# CREDIT
# {'49100', '14848', '12228', '5328', '10773', '26720', '4469', '36805', '12995', '14820', '3604', '36260', '5310', '10960', '35767,4', '8892', '18361', '10860', '12206', '7128', '7050', '7839', '9994', '42228', '25898', '83407', '31696', '29661', '24220', '5989', '12670', '2152', '6020', '9169', '21919', '18012', '25920', '22395', '13087', '23890', '3168', '3387', '19446', '6652', '44500', '14215', '22692', '5105,7', '3001', '20079', '24281', '27744', '6419,78', '23516,84', '12195', '15214', '10320', '5592', '5208', '8940', '4911', '10655', '30422', '24630', '4610', '4042', '10880', '75500', '5340', '8424', '21717,92', '12870', '39980', '29898', '6411,72', '30324', '14004', '17220', '4617', '12845', '6732', '13940', '9246', '3123', '11063', '15670', '41125,88', '9095', '21270', '11550', '13750', '18578', '21481', '19315', '16998', '12597,3', '78390', '17330', '15442', '22047', '20475', '28557', '11227', '35522', '20786', '23137', '22959', '6721', '19886', '21505', '3405', '2844', '6370', '6580', '19840', '4107', '18643', '9396', '10480', '18269', '11389,2', '7317', '6881', '21850', '5005,8', '7030', '16660', '5089', '8398,1', '2907', '8920', '74690', '28042', '3801', '24423', '6180', '25400', '31680', '4495', '60500', '30825', '8360', '16
729,07', '3716,35', '809,42', '2518,18', '1250', '1710', '400', '3970', '1052,63', '367', '457,71', '1080', '4770', '3150', '1650', '1931,44', '722,59', '836,79', '2750', '1940', '533', '6660', '777,84', '846,74', '1140', '2005,15', '1640', '630,49', '8020', '2520', '776,3', '6133,41', '3890', '4220', '818,74', '3860,18', '1150', '2732,2', '1065,62', '710', '4700', '5410', '1910', '3200', '1650,53', '1489,13', '726,57', '791,56', '6310', '1692,49', '5780', '1909,16', '901,64', '3520', '2510', '2707,25', '910', '3020', '600,93', '3260', '1519,64', '480', '1200,99', '1848,05', '3910', '2130', '846,55', '862,5', '1733,88', '648,68', '2060', '2679,82', '2365,47', '6260', '1600', '2920', '2751,25', '2100', '930', '4880', '2157,32', '2950', '840', '370', '997,66', '2000', '2009', '2647,9', '3060', '1930', '3762,5', '3018,62', '3400', '2380', '4680', '856,64', '3700', '776,6', '2509,38', '1030', '943,56', '3357,52', '1130', '1670,18', '590', '567,51', '2441,4', '669,12', '4390', '1860,72', '62,46', '3620', '1138,2', '1230', '1400', '2530', '1729,66', '2701,26', '1391,47', '887,79', '2349,51', '4300', '2569,05', '1740,19', '954,65', '1249,61', '3433,42', '1679,2', '802,36', '3230', '1789,04', '3360', '5030', '850', '2969,75', '1056,64', '1980', '3000', '1986,88', '14870', '2782,93', '2840', '2419,9', '1120,93', '665,57', '2270', '63,31', '918,28', '578,3', '908,78', '4210', '2059,46', '4030', '1299,55', '2094,3', '2154,02', '481,51', '1480', '1387,47', '3450', '2030', '1056,95', '957,4', '5075,99', '880,2', '530', '5603,82', '1666,28', '2618,78', '1942,72', '1840', '1597,92', '1563,45', '1870', '660', '3750', '1066', '2240', '1427,4', '1020', '2340', '1439,94', '540', '3635,77', '240', '1380', '2570', '1292,59', '1671,7', '1851,55', '2480', '1508,79', '820', '289,02', '3540', '1889,43', '1134,58', '3420', '668,53', '1127,76', '730', '6490', '2406,8', '789,23', '2265', '3964,85', '1939,61', '3111,86', '1387,15', '2916,18', '750', '783', '4250', '790,77', '1371,86', '2119,77', '473,16', '339,83', '1160', '4070', '2590,15', '543,17', '1070,52', '2163,94', '567,16', '2375,59', '796,59', '1033', '3300', '1320', '840,4', '1626,75', '4640', '900', '2400', '366,58', '2170', '766,26', '769,43', '1310', '755,76', '1509,44', '1398,58', '3820', '3760', '1090,8', '300',  ...
#
#
# ==========
# sample
# {'train'}

# %% [markdown]
# Mожно заметить что некоторые переменные, которые обозначены как строки (например PERSONAL_INCOME) на самом деле числа, но по какой-то причине были распознаны как строки
#
# Причина же что использовалась запятая для разделения не целой части числа..

# %% [markdown]
# Перекодировать их можно например так:

# %%
df['PERSONAL_INCOME'].map(lambda x: x.replace(',', '.')).astype('float')
# Out:
# 0         7000.0
# 1         4100.0
# 2        40000.0
# 3        20000.0
# 4        17000.0
# 5         7000.0
# 6        10000.0
# 7         7500.0
# 8         9000.0
# 9         4000.0
# 10       15000.0
# 11       12000.0
# 12        8000.0
# 13       20000.0
# 14       18500.0
# 15       14000.0
# 16        6000.0
# 17        9000.0
# 18        5000.0
# 19       15000.0
# 20        6100.0
# 21       22180.0
# 22        9000.0
# 23        8700.0
# 24        7000.0
# 25        6000.0
# 26       15000.0
# 27       12000.0
# 28       11000.0
# 29        8000.0
#           ...
# 30103    12000.0
# 30104    10000.0
# 30105    10000.0
# 30106     8000.0
# 30107    11000.0
# 30108     7000.0
# 30109    10000.0
# 30110     8000.0
# 30111    25000.0
# 30112    10000.0
# 30113    12000.0
# 30114     7000.0
# 30115    12000.0
# 30116    14500.0
# 30117    12000.0
# 30118     8000.0
# 30119     7000.0
# 30120    10000.0
# 30121    10000.0
# 30122    10000.0
# 30123    15000.0
# 30124     8100.0
# 30125     9500.0
# 30126    13000.0
# 30127    10000.0
# 30128    12000.0
# 30129    10000.0
# 30130     6000.0
# 30131     4500.0
# 30132    20000.0
# Name: PERSONAL_INCOME, Length: 30133, dtype: float64

# %% [markdown]
# Такой эффект наблюдается в столбцах `PERSONAL_INCOME`, `CREDIT`, `FST_PAYMENT`, `LOAN_AVG_DLQ_AMT`, `LOAN_MAX_DLQ_AMT`

# %% [markdown]
# ### Теперь ваше небольшое исследование

# %% [markdown]
# #### Задание 1. Есть ли пропуски в данных? Что с ними сделать?
#
# (единственного верного ответа нет - аргументируйте)

# %%
#В зависимости от задачи - заполнить пропуски нулями, единицами, средним или медианой. 
#Также можно удалить столбец с пропусками или удалить строки с пропусками.

# %% [markdown]
# #### Задание 2. Есть ли категориальные признаки? Что с ними делать?

# %%
#Можно закодировать категории цифрами 1,2,3, но тогда категории будут не равнозначны. 
#Или добавить новые столбцы по числу категорий, в которые записывать 1, если столбец 
#соответствует признаку, присущему данной сущности и 0, если не соответствует.

# %% [markdown]
# #### Задание 3. Фунция предобработки

# %% [markdown]
# Напишите функцию, которая бы
#
# * Удаляло идентификатор `AGREEMENT_RK`
# * Избавлялась от проблем с '.' и ',' в стобцах PERSONAL_INCOME, CREDIT, FST_PAYMENT, LOAN_AVG_DLQ_AMT, LOAN_MAX_DLQ_AMT
# * Что-то делала с пропусками
# * Кодировала категориальные признаки
#
# В результате, ваш датафрейм должен содержать только числа и не содержать пропусков!

# %%
def preproc_data(df_input):
    df_output = df_input.copy()
    
    df_output = df_output.drop(['AGREEMENT_RK'], axis=1)
    
    df_output['PERSONAL_INCOME']=df_output['PERSONAL_INCOME'].map(lambda x: x.replace(',', '.')).astype('float')
    df_output['CREDIT']=df_output['CREDIT'].map(lambda x: x.replace(',', '.')).astype('float')
    df_output['FST_PAYMENT']=df_output['FST_PAYMENT'].map(lambda x: x.replace(',', '.')).astype('float')
    df_output['LOAN_AVG_DLQ_AMT']=df_output['LOAN_AVG_DLQ_AMT'].map(lambda x: x.replace(',', '.')).astype('float')
    df_output['LOAN_MAX_DLQ_AMT']=df_output['LOAN_MAX_DLQ_AMT'].map(lambda x: x.replace(',', '.')).astype('float')
    
    #df.Age.fillna(df.Age.mean())
    df_output.WORK_TIME=df_output.WORK_TIME.fillna(df_output.WORK_TIME.mean())
    df_output.PREVIOUS_CARD_NUM_UTILIZED=df_output.PREVIOUS_CARD_NUM_UTILIZED.fillna(0)
    #df_output.WORK_TIME[df_output.WORK_TIME.isnull()] = df_output.WORK_TIME.mean()
    #df_output.PREVIOUS_CARD_NUM_UTILIZED[df_output.PREVIOUS_CARD_NUM_UTILIZED.isnull()] = 0
    #df_output.GEN_INDUSTRY.fillna('не задано')                  
    #df_output.GEN_TITLE.fillna('не задано')                     
    #df_output.ORG_TP_STATE.fillna('не задано')                   
    #df_output.ORG_TP_FCAPITAL.fillna('не задано')                
    #df_output.JOB_DIR.fillna('не задано')         
    #df_output.TP_PROVINCE.fillna('не задано')    
    df_output=pd.get_dummies(df_output,columns=['EDUCATION','MARITAL_STATUS','GEN_INDUSTRY','GEN_TITLE','ORG_TP_STATE','ORG_TP_FCAPITAL','JOB_DIR','FAMILY_INCOME','REG_ADDRESS_PROVINCE','FACT_ADDRESS_PROVINCE','POSTAL_ADDRESS_PROVINCE','TP_PROVINCE','REGION_NM'])    
    return df_output
df_preproc = df.pipe(preproc_data)
#abv=df_preproc.head()
#abv.T
df_preproc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30133 entries, 0 to 30132
# Columns: 444 entries, TARGET to REGION_NM_ЮЖНЫЙ
# dtypes: float64(7), int64(31), object(1), uint8(405)
# memory usage: 20.6+ MB

# %%
df_preproc = df.pipe(preproc_data)

df_train_preproc = df_preproc.query('sample == "train"').drop(['sample'], axis=1)
df_test_preproc = df_preproc.query('sample == "test"').drop(['sample'], axis=1)

# %% [markdown]
# #### Задание 4. Отделите целевую переменную и остальные признаки
#
# Должно получится:
# * 2 матрицы: X и X_test
# * 2 вектора: y и y_test

# %%
from sklearn.cross_validation import train_test_split
y=df_preproc['TARGET']
df_preproc = df_preproc.drop(['TARGET'], axis=1)
X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.3, random_state=42)
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# #### Задание 5. Обучение и оценка качества разных моделей

# %%
#from sklearn.cross_validation import train_test_split
# test_size=0.3, random_state=42

#X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.3, random_state=42)
#y_train=df_train_preproc['TARGET']
#df_train_preproc = df_train_preproc.drop(['TARGET'], axis=1)

# %%
#y_test=df_test_preproc['TARGET']
#df_test_preproc = df_test_preproc.drop(['TARGET'], axis=1)

# %%
#df_train_preproc.info()

# %%
# Попробовать следующие "черные ящики": интерфейс одинаковый 
#     fit, 
#     predict, 
#     predict_proba

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

## Your Code Here

classifiers = { 
    'dtc' : DecisionTreeClassifier(),
    'rfc' : RandomForestClassifier(),
    'lr' : LogisticRegression(),
}

for key, c in classifiers.items():
    c.fit(X_train, y_train)
    predict = c.predict(X_test)
    
    print('%s \t precision' % key, precision_score(y_test, predict))
    print('%s \t recall' % key, recall_score(y_test, predict))
    print('%s \t accuracy' % key, accuracy_score(y_test, predict))
    print('\n')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-e9a803c06334> in <module>()
#      17
#      18 for key, c in classifiers.items():
# ---> 19     c.fit(X_train, y_train)
#      20     predict = c.predict(X_test)
#      21
#
# /usr/local/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     788             sample_weight=sample_weight,
#     789             check_input=check_input,
# --> 790             X_idx_sorted=X_idx_sorted)
#     791         return self
#     792
#
# /usr/local/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     114         random_state = check_random_state(self.random_state)
#     115         if check_input:
# --> 116             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     117             y = check_array(y, ensure_2d=False, dtype=None)
#     118             if issparse(X):
#
# /usr/local/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ValueError: could not convert string to float: 'train'

# %%
# Посчитать метрики стандартные
# accuracy, precision, recall

from sklearn.metrics import accuracy_score, precision_score, recall_score

print('precision', precision_score(y_test, predict))
print('recall', recall_score(y_test, predict))
print('accuracy', accuracy_score(y_test, predict))

# %%
recall_score(y_test, predict)

# %%
# Визуалищировать эти метрики всех моделей на одном графике (чтоб визуально посмотреть)

import matplotlib.pylab as plt

lists = sorted(d.items()) # sorted by key, return a list of tuples

x, y = zip(*lists) # unpack a list of pairs into two tuples

plt.plot(x, y)
plt.show()

# %%
# Потроить roc-кривые всех можелей на одном графике
# Вывести roc_auc каждой моделе

## Your Code Here

# %%
from sklearn.cross_validation import cross_val_score
from sklearn.model_selection import StratifiedKFold
# Сделать k-fold (10 фолдов) кросс-валидацию каждой модели
# И посчитать средний roc_auc
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=123)

## Your Code Here

# %%
# Взять лучшую модель и сделать predict (с вероятностями (!!!)) для test выборки


## Your Code Here

# %%
# Померить roc_auc на тесте
